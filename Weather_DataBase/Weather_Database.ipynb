# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 748

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['main']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(), "Country": city_country, "Lat": city_lat, "Lng": city_lng,
                         "Max Temp": city_max_temp, "Humidity": city_humidity, "Cloudiness": city_clouds, 
                          "Wind Speed": city_wind, "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint george
# Processing Record 2 of Set 1 | turukhansk
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | faya
# Processing Record 5 of Set 1 | maragogi
# Processing Record 6 of Set 1 | chumikan
# Processing Record 7 of Set 1 | gornopravdinsk
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | bandarbeyla
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | bathsheba
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | kibala
# Processing Record 14 of Set 1 | provideniya
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | lishui
# Processing Record 18 of Set 1 | yuli
# Processing Record 19 of Set 1 | mount isa
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | kokopo
# Processing Record 23 of Set 1 | teya
# Processing Record 24 of Set 1 | lagoa
# Processing Record 25 of Set 1 | pangnirtung
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | mao
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | tanabe
# Processing Record 32 of Set 1 | lucapa
# Processing Record 33 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 1 | mugur-aksy
# Processing Record 35 of Set 1 | moose factory
# Processing Record 36 of Set 1 | ajdabiya
# Processing Record 37 of Set 1 | zhitikara
# City not found. Skipping...
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | wenzhou
# Processing Record 40 of Set 1 | husavik
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | vao
# Processing Record 43 of Set 1 | vagamo
# Processing Record 44 of Set 1 | abha
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | shahreza
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | shelburne
# Processing Record 49 of Set 1 | klobuck
# Processing Record 50 of Set 1 | coquimbo
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | porto novo
# Processing Record 3 of Set 2 | merrill
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | broome
# Processing Record 10 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | zdvinsk
# Processing Record 13 of Set 2 | kawalu
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | faanui
# Processing Record 17 of Set 2 | torbay
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | cidreira
# Processing Record 20 of Set 2 | harbour breton
# Processing Record 21 of Set 2 | acapulco
# Processing Record 22 of Set 2 | negotin
# Processing Record 23 of Set 2 | port moresby
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | alekseyevsk
# Processing Record 26 of Set 2 | acarau
# Processing Record 27 of Set 2 | lata
# Processing Record 28 of Set 2 | huron
# Processing Record 29 of Set 2 | paamiut
# Processing Record 30 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | viedma
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | sobolevo
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | cairns
# Processing Record 42 of Set 2 | westport
# Processing Record 43 of Set 2 | sitka
# Processing Record 44 of Set 2 | buraydah
# Processing Record 45 of Set 2 | geraldton
# Processing Record 46 of Set 2 | bud
# Processing Record 47 of Set 2 | champerico
# Processing Record 48 of Set 2 | lake charles
# Processing Record 49 of Set 2 | fethiye
# Processing Record 50 of Set 2 | qaqortoq
# Processing Record 1 of Set 3 | cotusca
# Processing Record 2 of Set 3 | lakatoro
# Processing Record 3 of Set 3 | gilgit
# Processing Record 4 of Set 3 | vanavara
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 3 | korla
# Processing Record 8 of Set 3 | hobart
# Processing Record 9 of Set 3 | carauari
# Processing Record 10 of Set 3 | airai
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | greenville
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | demba
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | dunedin
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | barmer
# Processing Record 20 of Set 3 | toora-khem
# Processing Record 21 of Set 3 | severo-kurilsk
# Processing Record 22 of Set 3 | poum
# Processing Record 23 of Set 3 | taybad
# Processing Record 24 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 3 | vanimo
# Processing Record 26 of Set 3 | buala
# Processing Record 27 of Set 3 | quelimane
# Processing Record 28 of Set 3 | tuyen quang
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | san patricio
# Processing Record 31 of Set 3 | santa marta
# Processing Record 32 of Set 3 | fuxin
# Processing Record 33 of Set 3 | paita
# Processing Record 34 of Set 3 | tvoroyri
# Processing Record 35 of Set 3 | kayerkan
# Processing Record 36 of Set 3 | severnoye
# Processing Record 37 of Set 3 | fierze
# City not found. Skipping...
# Processing Record 38 of Set 3 | podor
# Processing Record 39 of Set 3 | mogzon
# Processing Record 40 of Set 3 | hvammstangi
# City not found. Skipping...
# Processing Record 41 of Set 3 | toropets
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | yenagoa
# Processing Record 44 of Set 3 | jardim
# Processing Record 45 of Set 3 | port-cartier
# Processing Record 46 of Set 3 | arraial do cabo
# Processing Record 47 of Set 3 | egvekinot
# Processing Record 48 of Set 3 | soe
# Processing Record 49 of Set 3 | dvinskoy
# Processing Record 50 of Set 3 | willemstad
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | ahipara
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | tecoanapa
# Processing Record 5 of Set 4 | gerash
# Processing Record 6 of Set 4 | zhaotong
# Processing Record 7 of Set 4 | butaritari
# Processing Record 8 of Set 4 | yaan
# Processing Record 9 of Set 4 | okandja
# City not found. Skipping...
# Processing Record 10 of Set 4 | the valley
# Processing Record 11 of Set 4 | evensk
# Processing Record 12 of Set 4 | nogales
# Processing Record 13 of Set 4 | jamestown
# Processing Record 14 of Set 4 | lima
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | adre
# Processing Record 17 of Set 4 | souillac
# Processing Record 18 of Set 4 | dobbs ferry
# Processing Record 19 of Set 4 | san quintin
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | svetlyy
# Processing Record 22 of Set 4 | phan thiet
# Processing Record 23 of Set 4 | ulaangom
# Processing Record 24 of Set 4 | hirara
# Processing Record 25 of Set 4 | bambanglipuro
# Processing Record 26 of Set 4 | buri
# Processing Record 27 of Set 4 | sabang
# Processing Record 28 of Set 4 | constitucion
# Processing Record 29 of Set 4 | port-gentil
# Processing Record 30 of Set 4 | opuwo
# Processing Record 31 of Set 4 | tevriz
# Processing Record 32 of Set 4 | lowicz
# Processing Record 33 of Set 4 | nadym
# Processing Record 34 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 4 | umm lajj
# Processing Record 36 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 4 | tura
# Processing Record 38 of Set 4 | naze
# Processing Record 39 of Set 4 | cabo san lucas
# Processing Record 40 of Set 4 | dikson
# Processing Record 41 of Set 4 | tuktoyaktuk
# Processing Record 42 of Set 4 | alekseyevka
# Processing Record 43 of Set 4 | katol
# Processing Record 44 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 45 of Set 4 | chirongui
# Processing Record 46 of Set 4 | morant bay
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | mount gambier
# Processing Record 49 of Set 4 | lavrentiya
# Processing Record 50 of Set 4 | carutapera
# Processing Record 1 of Set 5 | vestmannaeyjar
# Processing Record 2 of Set 5 | iquique
# Processing Record 3 of Set 5 | tazovskiy
# Processing Record 4 of Set 5 | fukue
# Processing Record 5 of Set 5 | kavaratti
# Processing Record 6 of Set 5 | tuatapere
# Processing Record 7 of Set 5 | san ramon
# Processing Record 8 of Set 5 | novobiryusinskiy
# Processing Record 9 of Set 5 | luderitz
# Processing Record 10 of Set 5 | aranos
# Processing Record 11 of Set 5 | fredericton
# Processing Record 12 of Set 5 | novyy urgal
# Processing Record 13 of Set 5 | altay
# Processing Record 14 of Set 5 | rio grande
# Processing Record 15 of Set 5 | olden
# Processing Record 16 of Set 5 | vila velha
# Processing Record 17 of Set 5 | presque isle
# Processing Record 18 of Set 5 | muscat
# Processing Record 19 of Set 5 | hamilton
# Processing Record 20 of Set 5 | barrow
# Processing Record 21 of Set 5 | shache
# Processing Record 22 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 5 | nanortalik
# Processing Record 24 of Set 5 | makakilo city
# Processing Record 25 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 5 | lixourion
# Processing Record 27 of Set 5 | abalak
# Processing Record 28 of Set 5 | east london
# Processing Record 29 of Set 5 | ribeira grande
# Processing Record 30 of Set 5 | road town
# Processing Record 31 of Set 5 | aksehir
# Processing Record 32 of Set 5 | avera
# Processing Record 33 of Set 5 | maroantsetra
# Processing Record 34 of Set 5 | acajutla
# Processing Record 35 of Set 5 | quatre cocos
# Processing Record 36 of Set 5 | milkovo
# Processing Record 37 of Set 5 | chemal
# Processing Record 38 of Set 5 | maniitsoq
# Processing Record 39 of Set 5 | cherskiy
# Processing Record 40 of Set 5 | panaba
# Processing Record 41 of Set 5 | mitsamiouli
# Processing Record 42 of Set 5 | saint-georges
# Processing Record 43 of Set 5 | shelby
# Processing Record 44 of Set 5 | isla vista
# Processing Record 45 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 5 | chokurdakh
# Processing Record 47 of Set 5 | bairiki
# Processing Record 48 of Set 5 | nueva italia de ruiz
# Processing Record 49 of Set 5 | gat
# Processing Record 50 of Set 5 | myitkyina
# Processing Record 1 of Set 6 | hovd
# Processing Record 2 of Set 6 | santa isabel
# Processing Record 3 of Set 6 | oranjemund
# Processing Record 4 of Set 6 | black river
# Processing Record 5 of Set 6 | narsaq
# Processing Record 6 of Set 6 | bambous virieux
# Processing Record 7 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 6 | tres arroyos
# Processing Record 9 of Set 6 | roma
# Processing Record 10 of Set 6 | gao
# Processing Record 11 of Set 6 | lompoc
# Processing Record 12 of Set 6 | labuhan
# Processing Record 13 of Set 6 | zhigansk
# Processing Record 14 of Set 6 | samana
# Processing Record 15 of Set 6 | victoria
# Processing Record 16 of Set 6 | coracora
# Processing Record 17 of Set 6 | bacolod
# Processing Record 18 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 19 of Set 6 | belyy yar
# Processing Record 20 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 21 of Set 6 | saint-joseph
# Processing Record 22 of Set 6 | lasa
# Processing Record 23 of Set 6 | acuna
# City not found. Skipping...
# Processing Record 24 of Set 6 | alappuzha
# Processing Record 25 of Set 6 | bedele
# Processing Record 26 of Set 6 | micheweni
# Processing Record 27 of Set 6 | codrington
# Processing Record 28 of Set 6 | lazurne
# Processing Record 29 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | kudahuvadhoo
# Processing Record 31 of Set 6 | borba
# Processing Record 32 of Set 6 | qaanaaq
# Processing Record 33 of Set 6 | cayenne
# Processing Record 34 of Set 6 | marmato
# Processing Record 35 of Set 6 | kalachinsk
# Processing Record 36 of Set 6 | tay ninh
# Processing Record 37 of Set 6 | aswan
# Processing Record 38 of Set 6 | povenets
# Processing Record 39 of Set 6 | fiche
# Processing Record 40 of Set 6 | mudgee
# Processing Record 41 of Set 6 | henzada
# City not found. Skipping...
# Processing Record 42 of Set 6 | san antonio
# Processing Record 43 of Set 6 | yara
# Processing Record 44 of Set 6 | kangaatsiaq
# Processing Record 45 of Set 6 | yeppoon
# Processing Record 46 of Set 6 | bairnsdale
# Processing Record 47 of Set 6 | macas
# Processing Record 48 of Set 6 | upernavik
# Processing Record 49 of Set 6 | karratha
# Processing Record 50 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 7 | kapuskasing
# Processing Record 2 of Set 7 | suntar
# Processing Record 3 of Set 7 | fallon
# Processing Record 4 of Set 7 | samarai
# Processing Record 5 of Set 7 | hithadhoo
# Processing Record 6 of Set 7 | jacobina
# Processing Record 7 of Set 7 | christchurch
# Processing Record 8 of Set 7 | comodoro rivadavia
# Processing Record 9 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 7 | grand baie
# Processing Record 11 of Set 7 | najran
# Processing Record 12 of Set 7 | sri aman
# Processing Record 13 of Set 7 | hof
# Processing Record 14 of Set 7 | emerald
# Processing Record 15 of Set 7 | bay roberts
# Processing Record 16 of Set 7 | yulara
# Processing Record 17 of Set 7 | auki
# Processing Record 18 of Set 7 | charlestown
# Processing Record 19 of Set 7 | chake chake
# Processing Record 20 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 7 | coalcoman
# City not found. Skipping...
# Processing Record 22 of Set 7 | coihaique
# Processing Record 23 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 24 of Set 7 | swan river
# Processing Record 25 of Set 7 | ovsyanka
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 7 | port elizabeth
# Processing Record 29 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 7 | great yarmouth
# Processing Record 31 of Set 7 | tsaratanana
# Processing Record 32 of Set 7 | mamallapuram
# Processing Record 33 of Set 7 | nayoro
# Processing Record 34 of Set 7 | aklavik
# Processing Record 35 of Set 7 | ostrovnoy
# Processing Record 36 of Set 7 | labrea
# Processing Record 37 of Set 7 | mehamn
# Processing Record 38 of Set 7 | whitehorse
# Processing Record 39 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 7 | berezovyy
# Processing Record 41 of Set 7 | college
# Processing Record 42 of Set 7 | bilma
# Processing Record 43 of Set 7 | katherine
# Processing Record 44 of Set 7 | golden
# Processing Record 45 of Set 7 | kultuk
# Processing Record 46 of Set 7 | rong kwang
# Processing Record 47 of Set 7 | mani
# Processing Record 48 of Set 7 | portland
# Processing Record 49 of Set 7 | esperance
# Processing Record 50 of Set 7 | buzmeyin
# Processing Record 1 of Set 8 | kulu
# Processing Record 2 of Set 8 | cornesti
# Processing Record 3 of Set 8 | leshukonskoye
# Processing Record 4 of Set 8 | marienburg
# Processing Record 5 of Set 8 | dudinka
# Processing Record 6 of Set 8 | marsa matruh
# Processing Record 7 of Set 8 | nouakchott
# Processing Record 8 of Set 8 | maha sarakham
# Processing Record 9 of Set 8 | belogorsk
# Processing Record 10 of Set 8 | chuy
# Processing Record 11 of Set 8 | okhotsk
# Processing Record 12 of Set 8 | pevek
# Processing Record 13 of Set 8 | borogontsy
# Processing Record 14 of Set 8 | goderich
# Processing Record 15 of Set 8 | vostok
# Processing Record 16 of Set 8 | laguna
# Processing Record 17 of Set 8 | port hardy
# Processing Record 18 of Set 8 | ayagoz
# Processing Record 19 of Set 8 | san cristobal
# Processing Record 20 of Set 8 | bahia blanca
# Processing Record 21 of Set 8 | okha
# Processing Record 22 of Set 8 | korem
# Processing Record 23 of Set 8 | beloha
# Processing Record 24 of Set 8 | vila franca do campo
# Processing Record 25 of Set 8 | zhezkazgan
# Processing Record 26 of Set 8 | kupang
# Processing Record 27 of Set 8 | zemio
# Processing Record 28 of Set 8 | muros
# Processing Record 29 of Set 8 | tautira
# Processing Record 30 of Set 8 | olafsvik
# Processing Record 31 of Set 8 | marolambo
# Processing Record 32 of Set 8 | nichinan
# Processing Record 33 of Set 8 | andenes
# Processing Record 34 of Set 8 | asau
# Processing Record 35 of Set 8 | ancud
# Processing Record 36 of Set 8 | ahuimanu
# Processing Record 37 of Set 8 | luganville
# Processing Record 38 of Set 8 | salalah
# Processing Record 39 of Set 8 | bilibino
# Processing Record 40 of Set 8 | saint anthony
# Processing Record 41 of Set 8 | chernyanka
# Processing Record 42 of Set 8 | maues
# Processing Record 43 of Set 8 | qasigiannguit
# Processing Record 44 of Set 8 | marsh harbour
# Processing Record 45 of Set 8 | mayo
# Processing Record 46 of Set 8 | hofn
# Processing Record 47 of Set 8 | praya
# Processing Record 48 of Set 8 | riohacha
# Processing Record 49 of Set 8 | leningradskiy
# Processing Record 50 of Set 8 | gympie
# Processing Record 1 of Set 9 | atar
# Processing Record 2 of Set 9 | meyrin
# Processing Record 3 of Set 9 | jalu
# Processing Record 4 of Set 9 | baherden
# Processing Record 5 of Set 9 | vikarabad
# Processing Record 6 of Set 9 | half moon bay
# Processing Record 7 of Set 9 | inyonga
# Processing Record 8 of Set 9 | rorvik
# Processing Record 9 of Set 9 | medina del campo
# Processing Record 10 of Set 9 | artyom
# Processing Record 11 of Set 9 | caldwell
# Processing Record 12 of Set 9 | iisaku
# Processing Record 13 of Set 9 | hearst
# Processing Record 14 of Set 9 | mabaruma
# Processing Record 15 of Set 9 | norman wells
# Processing Record 16 of Set 9 | clonakilty
# Processing Record 17 of Set 9 | camacha
# Processing Record 18 of Set 9 | lamu
# Processing Record 19 of Set 9 | sur
# Processing Record 20 of Set 9 | fortuna
# Processing Record 21 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 9 | taonan
# Processing Record 23 of Set 9 | punta alta
# Processing Record 24 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 9 | pareora
# Processing Record 26 of Set 9 | beipiao
# Processing Record 27 of Set 9 | kondoa
# Processing Record 28 of Set 9 | strezhevoy
# Processing Record 29 of Set 9 | vila
# Processing Record 30 of Set 9 | ho
# City not found. Skipping...
# Processing Record 31 of Set 9 | dhidhdhoo
# Processing Record 32 of Set 9 | havoysund
# Processing Record 33 of Set 9 | buin
# Processing Record 34 of Set 9 | kwinana
# Processing Record 35 of Set 9 | praia da vitoria
# Processing Record 36 of Set 9 | filadelfia
# Processing Record 37 of Set 9 | tayu
# Processing Record 38 of Set 9 | shenjiamen
# Processing Record 39 of Set 9 | arman
# Processing Record 40 of Set 9 | grand gaube
# Processing Record 41 of Set 9 | trelew
# Processing Record 42 of Set 9 | nevsehir
# Processing Record 43 of Set 9 | yablochnyy
# Processing Record 44 of Set 9 | chapais
# Processing Record 45 of Set 9 | san vicente de canete
# Processing Record 46 of Set 9 | tigzirt
# Processing Record 47 of Set 9 | alofi
# Processing Record 48 of Set 9 | port blair
# Processing Record 49 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 10 | coolum beach
# Processing Record 2 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 3 of Set 10 | mana
# Processing Record 4 of Set 10 | charters towers
# Processing Record 5 of Set 10 | tombouctou
# Processing Record 6 of Set 10 | mogadishu
# Processing Record 7 of Set 10 | pisco
# Processing Record 8 of Set 10 | morro bay
# Processing Record 9 of Set 10 | hambantota
# Processing Record 10 of Set 10 | yeniseysk
# Processing Record 11 of Set 10 | yatou
# Processing Record 12 of Set 10 | shingu
# Processing Record 13 of Set 10 | kloulklubed
# Processing Record 14 of Set 10 | fuerte olimpo
# Processing Record 15 of Set 10 | kropachevo
# Processing Record 16 of Set 10 | celestun
# Processing Record 17 of Set 10 | komsomolskiy
# Processing Record 18 of Set 10 | los llanos de aridane
# Processing Record 19 of Set 10 | adelanto
# Processing Record 20 of Set 10 | beringovskiy
# Processing Record 21 of Set 10 | ningbo
# Processing Record 22 of Set 10 | biloela
# Processing Record 23 of Set 10 | bima
# Processing Record 24 of Set 10 | klaksvik
# Processing Record 25 of Set 10 | brattleboro
# Processing Record 26 of Set 10 | turayf
# Processing Record 27 of Set 10 | ilulissat
# Processing Record 28 of Set 10 | olinda
# Processing Record 29 of Set 10 | denpasar
# Processing Record 30 of Set 10 | polunochnoye
# Processing Record 31 of Set 10 | tuy hoa
# Processing Record 32 of Set 10 | fort smith
# Processing Record 33 of Set 10 | nova soure
# Processing Record 34 of Set 10 | lerwick
# Processing Record 35 of Set 10 | labuan
# Processing Record 36 of Set 10 | castelnaudary
# Processing Record 37 of Set 10 | copperas cove
# Processing Record 38 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 10 | port lincoln
# Processing Record 40 of Set 10 | libohove
# Processing Record 41 of Set 10 | harper
# Processing Record 42 of Set 10 | matara
# Processing Record 43 of Set 10 | lisakovsk
# Processing Record 44 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 46 of Set 10 | chicama
# Processing Record 47 of Set 10 | dukat
# Processing Record 48 of Set 10 | amahai
# Processing Record 49 of Set 10 | humaita
# Processing Record 50 of Set 10 | morozovsk
# Processing Record 1 of Set 11 | mongoumba
# Processing Record 2 of Set 11 | port hedland
# Processing Record 3 of Set 11 | preobrazheniye
# Processing Record 4 of Set 11 | bengkulu
# Processing Record 5 of Set 11 | uruacu
# Processing Record 6 of Set 11 | yumen
# Processing Record 7 of Set 11 | levelland
# Processing Record 8 of Set 11 | rozsypne
# Processing Record 9 of Set 11 | seoul
# Processing Record 10 of Set 11 | king city
# Processing Record 11 of Set 11 | shyroke
# Processing Record 12 of Set 11 | vikulovo
# Processing Record 13 of Set 11 | keetmanshoop
# Processing Record 14 of Set 11 | sola
# Processing Record 15 of Set 11 | beaverlodge
# Processing Record 16 of Set 11 | kahului
# Processing Record 17 of Set 11 | san felipe
# Processing Record 18 of Set 11 | orlik
# Processing Record 19 of Set 11 | mancio lima
# Processing Record 20 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 21 of Set 11 | angoche
# Processing Record 22 of Set 11 | lodja
# Processing Record 23 of Set 11 | smidovich
# Processing Record 24 of Set 11 | khatanga
# Processing Record 25 of Set 11 | lunderskov
# Processing Record 26 of Set 11 | gravelbourg
# Processing Record 27 of Set 11 | merauke
# Processing Record 28 of Set 11 | clyde river
# Processing Record 29 of Set 11 | praia
# Processing Record 30 of Set 11 | caravelas
# Processing Record 31 of Set 11 | americus
# Processing Record 32 of Set 11 | hobbs
# Processing Record 33 of Set 11 | vydrino
# Processing Record 34 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 35 of Set 11 | ciomas
# Processing Record 36 of Set 11 | orgtrud
# Processing Record 37 of Set 11 | redmond
# Processing Record 38 of Set 11 | baghdad
# Processing Record 39 of Set 11 | jiangyou
# Processing Record 40 of Set 11 | cochrane
# Processing Record 41 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 11 | arcata
# Processing Record 43 of Set 11 | tongling
# Processing Record 44 of Set 11 | zhicheng
# Processing Record 45 of Set 11 | naryan-mar
# Processing Record 46 of Set 11 | cascais
# Processing Record 47 of Set 11 | balkanabat
# Processing Record 48 of Set 11 | agirish
# Processing Record 49 of Set 11 | launceston
# Processing Record 50 of Set 11 | gwadar
# Processing Record 1 of Set 12 | ukiah
# Processing Record 2 of Set 12 | sorland
# Processing Record 3 of Set 12 | caluquembe
# Processing Record 4 of Set 12 | bosaso
# Processing Record 5 of Set 12 | afgoye
# City not found. Skipping...
# Processing Record 6 of Set 12 | burica
# City not found. Skipping...
# Processing Record 7 of Set 12 | dobryatino
# Processing Record 8 of Set 12 | ladario
# Processing Record 9 of Set 12 | machakos
# Processing Record 10 of Set 12 | lorengau
# Processing Record 11 of Set 12 | thano bula khan
# City not found. Skipping...
# Processing Record 12 of Set 12 | malanje
# Processing Record 13 of Set 12 | la sarre
# Processing Record 14 of Set 12 | ambulu
# Processing Record 15 of Set 12 | deer lake
# Processing Record 16 of Set 12 | santiago de cuba
# Processing Record 17 of Set 12 | elizabeth city
# Processing Record 18 of Set 12 | porumbacu de jos
# Processing Record 19 of Set 12 | evanston
# Processing Record 20 of Set 12 | clocolan
# Processing Record 21 of Set 12 | ketchikan
# Processing Record 22 of Set 12 | nuuk
# Processing Record 23 of Set 12 | kedrovyy
# Processing Record 24 of Set 12 | la ronge
# Processing Record 25 of Set 12 | vilhena
# Processing Record 26 of Set 12 | plouzane
# Processing Record 27 of Set 12 | ghanzi
# Processing Record 28 of Set 12 | morki
# Processing Record 29 of Set 12 | havelock
# Processing Record 30 of Set 12 | mayumba
# Processing Record 31 of Set 12 | nosy varika
# Processing Record 32 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 12 | thoen
# Processing Record 34 of Set 12 | aksu
# Processing Record 35 of Set 12 | walvis bay
# Processing Record 36 of Set 12 | lanzhou
# Processing Record 37 of Set 12 | bira
# Processing Record 38 of Set 12 | marau
# Processing Record 39 of Set 12 | kotaparh
# Processing Record 40 of Set 12 | kalmunai
# Processing Record 41 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 12 | rabo de peixe
# Processing Record 43 of Set 12 | namibe
# Processing Record 44 of Set 12 | yarega
# Processing Record 45 of Set 12 | caraballeda
# Processing Record 46 of Set 12 | orem
# Processing Record 47 of Set 12 | manaure
# Processing Record 48 of Set 12 | maracai
# Processing Record 49 of Set 12 | srandakan
# Processing Record 50 of Set 12 | nemuro
# Processing Record 1 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 13 | margate
# Processing Record 3 of Set 13 | bubaque
# Processing Record 4 of Set 13 | jalalabad
# Processing Record 5 of Set 13 | sungairaya
# Processing Record 6 of Set 13 | shirpur
# Processing Record 7 of Set 13 | alice springs
# Processing Record 8 of Set 13 | lumby
# Processing Record 9 of Set 13 | gazanjyk
# Processing Record 10 of Set 13 | fort nelson
# Processing Record 11 of Set 13 | polson
# Processing Record 12 of Set 13 | hobyo
# Processing Record 13 of Set 13 | staryy krym
# Processing Record 14 of Set 13 | kapit
# Processing Record 15 of Set 13 | bazarnyy karabulak
# Processing Record 16 of Set 13 | blagoyevo
# Processing Record 17 of Set 13 | itoman
# Processing Record 18 of Set 13 | itarema
# Processing Record 19 of Set 13 | nouadhibou
# Processing Record 20 of Set 13 | kasempa
# Processing Record 21 of Set 13 | bull savanna
# Processing Record 22 of Set 13 | mufumbwe
# Processing Record 23 of Set 13 | saint-louis
# Processing Record 24 of Set 13 | kamenka
# Processing Record 25 of Set 13 | fort-shevchenko
# Processing Record 26 of Set 13 | strelca
# City not found. Skipping...
# Processing Record 27 of Set 13 | neepawa
# Processing Record 28 of Set 13 | saint-pierre
# Processing Record 29 of Set 13 | banda aceh
# Processing Record 30 of Set 13 | liverpool
# Processing Record 31 of Set 13 | anchorage
# Processing Record 32 of Set 13 | devils lake
# Processing Record 33 of Set 13 | puerto carreno
# Processing Record 34 of Set 13 | santander
# Processing Record 35 of Set 13 | selenginsk
# Processing Record 36 of Set 13 | davila
# Processing Record 37 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 38 of Set 13 | stephenville
# Processing Record 39 of Set 13 | pandan
# Processing Record 40 of Set 13 | cruzeiro do sul
# Processing Record 41 of Set 13 | sangar
# Processing Record 42 of Set 13 | puerto ayacucho
# Processing Record 43 of Set 13 | aden
# Processing Record 44 of Set 13 | tutoia
# Processing Record 45 of Set 13 | ust-nera
# Processing Record 46 of Set 13 | lipin bor
# Processing Record 47 of Set 13 | kyra
# Processing Record 48 of Set 13 | bitung
# Processing Record 49 of Set 13 | ocean city
# Processing Record 50 of Set 13 | vitim
# Processing Record 1 of Set 14 | manokwari
# Processing Record 2 of Set 14 | teguise
# Processing Record 3 of Set 14 | bouca
# Processing Record 4 of Set 14 | sirjan
# Processing Record 5 of Set 14 | kamaishi
# Processing Record 6 of Set 14 | padang
# Processing Record 7 of Set 14 | providencia
# Processing Record 8 of Set 14 | seybaplaya
# Processing Record 9 of Set 14 | shelton
# Processing Record 10 of Set 14 | isabela
# Processing Record 11 of Set 14 | pemangkat
# Processing Record 12 of Set 14 | tatarsk
# Processing Record 13 of Set 14 | ucluelet
# Processing Record 14 of Set 14 | pozo colorado
# Processing Record 15 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 14 | innisfail
# Processing Record 17 of Set 14 | rio gallegos
# Processing Record 18 of Set 14 | algeciras
# Processing Record 19 of Set 14 | valparaiso
# Processing Record 20 of Set 14 | port macquarie
# Processing Record 21 of Set 14 | canutama
# Processing Record 22 of Set 14 | sabla
# Processing Record 23 of Set 14 | taoudenni
# Processing Record 24 of Set 14 | tlyarota
# City not found. Skipping...
# Processing Record 25 of Set 14 | santa cecilia
# Processing Record 26 of Set 14 | manicore
# Processing Record 27 of Set 14 | ohara
# Processing Record 28 of Set 14 | progreso
# Processing Record 29 of Set 14 | antofagasta
# Processing Record 30 of Set 14 | pishin
# Processing Record 31 of Set 14 | fasa
# Processing Record 32 of Set 14 | richards bay
# Processing Record 33 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 14 | dali
# Processing Record 35 of Set 14 | doka
# Processing Record 36 of Set 14 | darnah
# Processing Record 37 of Set 14 | saint-francois
# Processing Record 38 of Set 14 | thinadhoo
# Processing Record 39 of Set 14 | hella
# Processing Record 40 of Set 14 | koupela
# Processing Record 41 of Set 14 | kortkeros
# Processing Record 42 of Set 14 | neiafu
# Processing Record 43 of Set 14 | neka
# Processing Record 44 of Set 14 | lubango
# Processing Record 45 of Set 14 | seymchan
# Processing Record 46 of Set 14 | santa cruz cabralia
# Processing Record 47 of Set 14 | yurga
# Processing Record 48 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 14 | kaseda
# Processing Record 50 of Set 14 | bolgatanga
# Processing Record 1 of Set 15 | honolulu
# Processing Record 2 of Set 15 | bukachacha
# Processing Record 3 of Set 15 | denau
# City not found. Skipping...
# Processing Record 4 of Set 15 | leh
# Processing Record 5 of Set 15 | jumla
# Processing Record 6 of Set 15 | marystown
# Processing Record 7 of Set 15 | the pas
# Processing Record 8 of Set 15 | kenai
# Processing Record 9 of Set 15 | cuorgne
# Processing Record 10 of Set 15 | lahad datu
# Processing Record 11 of Set 15 | kedgwick
# Processing Record 12 of Set 15 | hervey bay
# Processing Record 13 of Set 15 | skibbereen
# Processing Record 14 of Set 15 | dingle
# Processing Record 15 of Set 15 | libres
# Processing Record 16 of Set 15 | gunjur
# Processing Record 17 of Set 15 | guerrero negro
# Processing Record 18 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 15 | pietarsaari
# Processing Record 20 of Set 15 | cabedelo
# Processing Record 21 of Set 15 | samur
# Processing Record 22 of Set 15 | dicabisagan
# Processing Record 23 of Set 15 | la tebaida
# Processing Record 24 of Set 15 | malatya
# Processing Record 25 of Set 15 | antsohihy
# Processing Record 26 of Set 15 | voskresenskoye
# Processing Record 27 of Set 15 | kerrville
# Processing Record 28 of Set 15 | takoradi
# Processing Record 29 of Set 15 | maceio
# Processing Record 30 of Set 15 | lac du bonnet
# Processing Record 31 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 15 | la chapelle-sur-erdre
# Processing Record 33 of Set 15 | kungurtug
# Processing Record 34 of Set 15 | kaeo
# Processing Record 35 of Set 15 | bjala
# City not found. Skipping...
# Processing Record 36 of Set 15 | te anau
# Processing Record 37 of Set 15 | tornio
# Processing Record 38 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 15 | bocaranga
# City not found. Skipping...
# Processing Record 40 of Set 15 | porto velho
# Processing Record 41 of Set 15 | marsaxlokk
# Processing Record 42 of Set 15 | jiuquan
# Processing Record 43 of Set 15 | puerto escondido
# Processing Record 44 of Set 15 | boyolangu
# Processing Record 45 of Set 15 | meulaboh
# Processing Record 46 of Set 15 | ust-ishim
# Processing Record 47 of Set 15 | nanchong
# Processing Record 48 of Set 15 | porkhov
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Saint George      US  37.1041 -113.5841    273.48        64           0
# 1      Turukhansk      RU  65.8167   87.9833    254.80        98         100
# 2       Busselton      AU -33.6500  115.3333    289.36        75           0
# 3            Faya      SA  18.3851   42.4509    293.21        52          20
# 4        Maragogi      BR  -9.0122  -35.2225    301.88        65          72
# 5        Chumikan      RU  54.7183  135.3150    254.77        81           8
# 6  Gornopravdinsk      RU  60.0500   69.9000    253.25        93          52
# 7          Atuona      PF  -9.8000 -139.0333    298.33        73          11
# 8     Bandarbeyla      SO   9.4942   50.8122    299.56        66          61
# 9     Port Alfred      ZA -33.5906   26.8910    296.03        77          88
#
#    Wind Speed Current Description
# 0        2.06               Clear
# 1        2.90              Clouds
# 2        6.79               Clear
# 3        3.09              Clouds
# 4        6.62              Clouds
# 5        7.62               Clear
# 6        2.55              Clouds
# 7        5.94              Clouds
# 8        8.59              Clouds
# 9        4.47              Clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Saint George      US  37.1041 -113.5841    273.48        64           0
# 1      Turukhansk      RU  65.8167   87.9833    254.80        98         100
# 2       Busselton      AU -33.6500  115.3333    289.36        75           0
# 3            Faya      SA  18.3851   42.4509    293.21        52          20
# 4        Maragogi      BR  -9.0122  -35.2225    301.88        65          72
# 5        Chumikan      RU  54.7183  135.3150    254.77        81           8
# 6  Gornopravdinsk      RU  60.0500   69.9000    253.25        93          52
# 7          Atuona      PF  -9.8000 -139.0333    298.33        73          11
# 8     Bandarbeyla      SO   9.4942   50.8122    299.56        66          61
# 9     Port Alfred      ZA -33.5906   26.8910    296.03        77          88
#
#    Wind Speed Current Description
# 0        2.06               Clear
# 1        2.90              Clouds
# 2        6.79               Clear
# 3        3.09              Clouds
# 4        6.62              Clouds
# 5        7.62               Clear
# 6        2.55              Clouds
# 7        5.94              Clouds
# 8        8.59              Clouds
# 9        4.47              Clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "./WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City ID")
